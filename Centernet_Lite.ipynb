# %%
from IPython.display import clear_output
clear_output()

# %%
import shutil

# Try to remove the tree; if it fails, throw an error using try...except.
try:
    shutil.rmtree("/content/sample_data")
except OSError as e:
    print("Error: %s - %s." % (e.filename, e.strerror))

# %%
# Clone from Github Repository
! git init .
! git remote add origin https://github.com/RichardMinsooGo-ML/Bible_4_Part_J_Centernet_Lite.git
# ! git pull origin master
! git pull origin main
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 86 (delta 2), reused 0 (delta 0), pack-reused 83
# Unpacking objects: 100% (86/86), 170.37 KiB | 1.16 MiB/s, done.
# From https://github.com/RichardMinsooGo-ML/Bible_4_Part_J_Centernet_Lite
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main

# %%
! pip install thop
# Out:
# Collecting thop
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from thop) (2.1.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->thop) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->thop) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->thop) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->thop) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->thop) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->thop) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->thop) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->thop) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->thop) (1.3.0)
# Installing collected packages: thop
# Successfully installed thop-0.1.1.post2209072238

# %%
# VOC 2012 Dataset Download and extract

! wget http://host.robots.ox.ac.uk/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar
# !tar -xvf "/content/VOCtrainval_11-May-2012.tar" -C "/content/data"
clear_output()

# %%
! wget http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
! wget http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar
# Out:
# --2024-01-10 05:28:11--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 460032000 (439M) [application/x-tar]
# Saving to: ‘VOCtrainval_06-Nov-2007.tar’
#
# VOCtrainval_06-Nov- 100%[===================>] 438.72M  13.4MB/s    in 34s
#
# 2024-01-10 05:28:46 (12.8 MB/s) - ‘VOCtrainval_06-Nov-2007.tar’ saved [460032000/460032000]
#
# --2024-01-10 05:28:46--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 451020800 (430M) [application/x-tar]
# Saving to: ‘VOCtest_06-Nov-2007.tar’
#
# VOCtest_06-Nov-2007 100%[===================>] 430.13M  13.4MB/s    in 35s
#
# 2024-01-10 05:29:22 (12.3 MB/s) - ‘VOCtest_06-Nov-2007.tar’ saved [451020800/451020800]

# %%
# !tar -xvf "/content/VOCtrainval_06-Nov-2007.tar" -C "/content/data"
# !tar -xvf "/content/VOCtest_06-Nov-2007.tar" -C "/content/data"
clear_output()

# %%
! wget http://images.cocodataset.org/zips/train2017.zip
! wget http://images.cocodataset.org/zips/val2017.zip
! wget http://images.cocodataset.org/zips/test2017.zip
# ! wget http://images.cocodataset.org/zips/unlabeled2017.zip


! unzip train2017.zip  -d dataset/COCO2017
! unzip val2017.zip  -d dataset/COCO2017
! unzip test2017.zip  -d dataset/COCO2017
clear_output()

# ! unzip test2017.zip
# clear_output()

# ! unzip unlabeled2017.zip
# clear_output()

# ! rm train2017.zip
# ! rm val2017.zip
# ! rm test2017.zip
# ! rm unlabeled2017.zip

! wget http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# wget http://images.cocodataset.org/annotations/stuff_annotations_trainval2017.zip
# wget http://images.cocodataset.org/annotations/image_info_test2017.zip
# wget http://images.cocodataset.org/annotations/image_info_unlabeled2017.zip

! unzip annotations_trainval2017.zip -d dataset/COCO2017
# ! unzip stuff_annotations_trainval2017.zip
# ! unzip image_info_test2017.zip
# ! unzip image_info_unlabeled2017.zip

# ! rm annotations_trainval2017.zip
# ! rm stuff_annotations_trainval2017.zip
# ! rm image_info_test2017.zip
# ! rm image_info_unlabeled2017.zip
# Out:
# --2023-12-29 00:26:55--  http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.216.52.153, 52.216.34.169, 52.217.171.249, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.216.52.153|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252907541 (241M) [application/zip]
# Saving to: ‘annotations_trainval2017.zip’
#
# annotations_trainva 100%[===================>] 241.19M  96.7MB/s    in 2.5s
#
# 2023-12-29 00:26:57 (96.7 MB/s) - ‘annotations_trainval2017.zip’ saved [252907541/252907541]
#
# Archive:  annotations_trainval2017.zip
#   inflating: dataset/COCO2017/annotations/instances_train2017.json
#   inflating: dataset/COCO2017/annotations/instances_val2017.json
#   inflating: dataset/COCO2017/annotations/captions_train2017.json
#   inflating: dataset/COCO2017/annotations/captions_val2017.json
#   inflating: dataset/COCO2017/annotations/person_keypoints_train2017.json
#   inflating: dataset/COCO2017/annotations/person_keypoints_val2017.json

# %%
! python train.py --cuda -d voc
# Out:
# Setting Arguments.. :  Namespace(version='centernet', backbone='r18', dataset='voc', multi_scale=False, batch_size=32, lr=0.001, cos=False, no_warm_up=False, wp_epoch=2, start_epoch=0, resume=None, momentum=0.9, weight_decay=0.0005, gamma=0.1, num_workers=8, eval_epoch=10, cuda=True, mosaic=False, tfboard=False, debug=False, save_folder='weights/')
# ----------------------------------------------------------
# use cuda
# Loading the dataset...
# Training model on: VOC0712
# The dataset size: 16551
# ----------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Use backbone : resnet-18
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# 100% 44.7M/44.7M [00:00<00:00, 81.0MB/s]
# Let us train centernet on the voc dataset ......
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# [Epoch 1/3][Iter 0/517][lr 0.000000][Loss: cls 8.75 || txty 4.51 || twth 19.61 ||total 32.88 || size 512 || time: 41.63]
# [Epoch 1/3][Iter 10/517][lr 0.000000][Loss: cls 7.52 || txty 3.72 || twth 16.01 ||total 27.25 || size 512 || time: 10.48]
# [Epoch 1/3][Iter 20/517][lr 0.000000][Loss: cls 9.90 || txty 5.27 || twth 22.95 ||total 38.12 || size 512 || time: 10.66]
# [Epoch 1/3][Iter 30/517][lr 0.000000][Loss: cls 11.53 || txty 6.27 || twth 27.99 ||total 45.80 || size 512 || time: 10.83]
# [Epoch 1/3][Iter 40/517][lr 0.000000][Loss: cls 9.26 || txty 4.98 || twth 21.70 ||total 35.93 || size 512 || time: 11.03]
# [Epoch 1/3][Iter 50/517][lr 0.000000][Loss: cls 9.90 || txty 5.49 || twth 21.49 ||total 36.88 || size 512 || time: 11.30]
# [Epoch 1/3][Iter 60/517][lr 0.000000][Loss: cls 10.31 || txty 5.74 || twth 23.32 ||total 39.37 || size 512 || time: 11.49]
# [Epoch 1/3][Iter 70/517][lr 0.000000][Loss: cls 7.84 || txty 4.01 || twth 19.31 ||total 31.16 || size 512 || time: 11.27]
# [Epoch 1/3][Iter 80/517][lr 0.000000][Loss: cls 9.84 || txty 5.15 || twth 21.39 ||total 36.38 || size 512 || time: 11.07]
# [Epoch 1/3][Iter 90/517][lr 0.000000][Loss: cls 11.02 || txty 5.96 || twth 25.11 ||total 42.08 || size 512 || time: 11.08]
# [Epoch 1/3][Iter 100/517][lr 0.000000][Loss: cls 9.38 || txty 5.10 || twth 19.71 ||total 34.20 || size 512 || time: 11.10]
# [Epoch 1/3][Iter 110/517][lr 0.000000][Loss: cls 10.18 || txty 5.11 || twth 21.33 ||total 36.63 || size 512 || time: 11.18]
# [Epoch 1/3][Iter 120/517][lr 0.000000][Loss: cls 11.65 || txty 6.30 || twth 25.33 ||total 43.28 || size 512 || time: 11.23]
# [Epoch 1/3][Iter 130/517][lr 0.000000][Loss: cls 11.90 || txty 6.45 || twth 25.62 ||total 43.97 || size 512 || time: 11.21]
# [Epoch 1/3][Iter 140/517][lr 0.000000][Loss: cls 7.82 || txty 4.11 || twth 18.46 ||total 30.39 || size 512 || time: 11.16]
# [Epoch 1/3][Iter 150/517][lr 0.000000][Loss: cls 9.78 || txty 5.15 || twth 21.92 ||total 36.85 || size 512 || time: 11.13]
# [Epoch 1/3][Iter 160/517][lr 0.000001][Loss: cls 11.49 || txty 6.25 || twth 24.95 ||total 42.69 || size 512 || time: 11.16]
# [Epoch 1/3][Iter 170/517][lr 0.000001][Loss: cls 7.89 || txty 3.85 || twth 18.35 ||total 30.09 || size 512 || time: 11.20]
# [Epoch 1/3][Iter 180/517][lr 0.000001][Loss: cls 12.31 || txty 6.85 || twth 28.37 ||total 47.53 || size 512 || time: 11.22]
# [Epoch 1/3][Iter 190/517][lr 0.000001][Loss: cls 10.87 || txty 5.74 || twth 21.55 ||total 38.16 || size 512 || time: 11.22]
# [Epoch 1/3][Iter 200/517][lr 0.000001][Loss: cls 9.99 || txty 5.53 || twth 20.99 ||total 36.51 || size 512 || time: 11.21]
# [Epoch 1/3][Iter 210/517][lr 0.000002][Loss: cls 9.65 || txty 5.19 || twth 21.75 ||total 36.60 || size 512 || time: 11.22]
# [Epoch 1/3][Iter 220/517][lr 0.000002][Loss: cls 8.13 || txty 4.07 || twth 16.97 ||total 29.17 || size 512 || time: 11.22]
# [Epoch 1/3][Iter 230/517][lr 0.000002][Loss: cls 7.21 || txty 3.73 || twth 16.85 ||total 27.79 || size 512 || time: 11.17]
# [Epoch 1/3][Iter 240/517][lr 0.000003][Loss: cls 10.63 || txty 5.78 || twth 20.27 ||total 36.67 || size 512 || time: 11.22]
# [Epoch 1/3][Iter 250/517][lr 0.000003][Loss: cls 8.22 || txty 4.14 || twth 16.85 ||total 29.20 || size 512 || time: 11.22]
# [Epoch 1/3][Iter 260/517][lr 0.000004][Loss: cls 8.57 || txty 4.49 || twth 15.44 ||total 28.50 || size 512 || time: 11.16]
# [Epoch 1/3][Iter 270/517][lr 0.000005][Loss: cls 8.78 || txty 4.82 || twth 15.01 ||total 28.61 || size 512 || time: 11.16]
# [Epoch 1/3][Iter 280/517][lr 0.000005][Loss: cls 8.62 || txty 4.62 || twth 15.92 ||total 29.16 || size 512 || time: 11.19]
# [Epoch 1/3][Iter 290/517][lr 0.000006][Loss: cls 8.18 || txty 4.30 || twth 14.17 ||total 26.65 || size 512 || time: 11.17]
# [Epoch 1/3][Iter 300/517][lr 0.000007][Loss: cls 8.54 || txty 4.44 || twth 11.41 ||total 24.39 || size 512 || time: 11.19]
# [Epoch 1/3][Iter 310/517][lr 0.000008][Loss: cls 9.22 || txty 4.95 || twth 14.61 ||total 28.78 || size 512 || time: 11.21]
# [Epoch 1/3][Iter 320/517][lr 0.000009][Loss: cls 11.41 || txty 6.44 || twth 14.88 ||total 32.73 || size 512 || time: 11.20]
# [Epoch 1/3][Iter 330/517][lr 0.000010][Loss: cls 10.32 || txty 5.66 || twth 13.66 ||total 29.64 || size 512 || time: 11.23]
# [Epoch 1/3][Iter 340/517][lr 0.000012][Loss: cls 8.21 || txty 4.11 || twth 9.09 ||total 21.42 || size 512 || time: 11.21]
# [Epoch 1/3][Iter 350/517][lr 0.000013][Loss: cls 8.07 || txty 4.12 || twth 11.72 ||total 23.91 || size 512 || time: 11.21]
# [Epoch 1/3][Iter 360/517][lr 0.000015][Loss: cls 10.03 || txty 5.64 || twth 10.19 ||total 25.86 || size 512 || time: 11.23]
# [Epoch 1/3][Iter 370/517][lr 0.000016][Loss: cls 7.36 || txty 4.17 || twth 6.91 ||total 18.44 || size 512 || time: 11.19]
# [Epoch 1/3][Iter 380/517][lr 0.000018][Loss: cls 6.93 || txty 3.63 || twth 7.35 ||total 17.92 || size 512 || time: 11.11]
# [Epoch 1/3][Iter 390/517][lr 0.000020][Loss: cls 8.10 || txty 4.45 || twth 6.89 ||total 19.44 || size 512 || time: 11.20]
# [Epoch 1/3][Iter 400/517][lr 0.000022][Loss: cls 7.62 || txty 4.10 || twth 6.09 ||total 17.80 || size 512 || time: 11.16]
# [Epoch 1/3][Iter 410/517][lr 0.000025][Loss: cls 7.84 || txty 3.90 || twth 8.32 ||total 20.07 || size 512 || time: 11.18]
# [Epoch 1/3][Iter 420/517][lr 0.000027][Loss: cls 9.80 || txty 5.54 || twth 8.46 ||total 23.80 || size 512 || time: 11.19]
# [Epoch 1/3][Iter 430/517][lr 0.000030][Loss: cls 9.14 || txty 5.41 || twth 6.15 ||total 20.70 || size 512 || time: 11.17]
# [Epoch 1/3][Iter 440/517][lr 0.000033][Loss: cls 8.32 || txty 4.46 || twth 6.08 ||total 18.86 || size 512 || time: 11.22]
# [Epoch 1/3][Iter 450/517][lr 0.000036][Loss: cls 7.31 || txty 4.26 || twth 6.36 ||total 17.93 || size 512 || time: 11.17]
# [Epoch 1/3][Iter 460/517][lr 0.000039][Loss: cls 7.80 || txty 4.26 || twth 5.04 ||total 17.11 || size 512 || time: 11.15]
# [Epoch 1/3][Iter 470/517][lr 0.000043][Loss: cls 9.73 || txty 5.77 || twth 6.04 ||total 21.54 || size 512 || time: 11.14]
# [Epoch 1/3][Iter 480/517][lr 0.000046][Loss: cls 9.29 || txty 5.79 || twth 4.68 ||total 19.76 || size 512 || time: 11.15]
# [Epoch 1/3][Iter 490/517][lr 0.000050][Loss: cls 9.13 || txty 5.32 || twth 4.12 ||total 18.57 || size 512 || time: 11.18]
# [Epoch 1/3][Iter 500/517][lr 0.000055][Loss: cls 8.28 || txty 4.92 || twth 3.23 ||total 16.43 || size 512 || time: 11.22]
# [Epoch 1/3][Iter 510/517][lr 0.000059][Loss: cls 8.62 || txty 4.67 || twth 3.65 ||total 16.93 || size 512 || time: 11.14]
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# [Epoch 2/3][Iter 0/517][lr 0.000063][Loss: cls 10.28 || txty 5.92 || twth 3.91 ||total 20.11 || size 512 || time: 21.93]
# [Epoch 2/3][Iter 10/517][lr 0.000067][Loss: cls 8.38 || txty 5.13 || twth 2.80 ||total 16.31 || size 512 || time: 11.16]
# [Epoch 2/3][Iter 20/517][lr 0.000073][Loss: cls 8.76 || txty 4.98 || twth 3.29 ||total 17.03 || size 512 || time: 11.15]
# [Epoch 2/3][Iter 30/517][lr 0.000078][Loss: cls 8.49 || txty 4.95 || twth 2.53 ||total 15.97 || size 512 || time: 11.16]
# [Epoch 2/3][Iter 40/517][lr 0.000084][Loss: cls 6.96 || txty 3.84 || twth 2.60 ||total 13.40 || size 512 || time: 11.23]
# [Epoch 2/3][Iter 50/517][lr 0.000090][Loss: cls 8.83 || txty 5.46 || twth 2.08 ||total 16.37 || size 512 || time: 11.14]
# [Epoch 2/3][Iter 60/517][lr 0.000097][Loss: cls 7.98 || txty 4.86 || twth 2.31 ||total 15.15 || size 512 || time: 11.14]
# [Epoch 2/3][Iter 70/517][lr 0.000104][Loss: cls 8.55 || txty 4.72 || twth 2.65 ||total 15.92 || size 512 || time: 11.15]
# [Epoch 2/3][Iter 80/517][lr 0.000111][Loss: cls 7.04 || txty 3.92 || twth 2.07 ||total 13.02 || size 512 || time: 11.12]
# [Epoch 2/3][Iter 90/517][lr 0.000119][Loss: cls 7.52 || txty 4.45 || twth 2.40 ||total 14.37 || size 512 || time: 11.09]
# [Epoch 2/3][Iter 100/517][lr 0.000127][Loss: cls 9.59 || txty 5.50 || twth 1.82 ||total 16.91 || size 512 || time: 11.13]
# [Epoch 2/3][Iter 110/517][lr 0.000135][Loss: cls 5.94 || txty 3.22 || twth 1.66 ||total 10.82 || size 512 || time: 11.20]
# [Epoch 2/3][Iter 120/517][lr 0.000144][Loss: cls 9.07 || txty 5.32 || twth 2.33 ||total 16.73 || size 512 || time: 11.14]
# [Epoch 2/3][Iter 130/517][lr 0.000153][Loss: cls 8.47 || txty 5.09 || twth 1.85 ||total 15.41 || size 512 || time: 11.21]
# [Epoch 2/3][Iter 140/517][lr 0.000163][Loss: cls 7.43 || txty 4.35 || twth 1.62 ||total 13.41 || size 512 || time: 11.19]
# [Epoch 2/3][Iter 150/517][lr 0.000173][Loss: cls 10.05 || txty 6.13 || twth 2.97 ||total 19.15 || size 512 || time: 11.17]
# [Epoch 2/3][Iter 160/517][lr 0.000184][Loss: cls 8.09 || txty 5.37 || twth 2.11 ||total 15.57 || size 512 || time: 11.17]
# [Epoch 2/3][Iter 170/517][lr 0.000195][Loss: cls 7.75 || txty 4.58 || twth 1.16 ||total 13.48 || size 512 || time: 11.15]
# [Epoch 2/3][Iter 180/517][lr 0.000206][Loss: cls 8.70 || txty 5.36 || twth 1.77 ||total 15.83 || size 512 || time: 11.17]
# [Epoch 2/3][Iter 190/517][lr 0.000219][Loss: cls 7.61 || txty 4.92 || twth 1.34 ||total 13.86 || size 512 || time: 11.13]
# [Epoch 2/3][Iter 200/517][lr 0.000231][Loss: cls 6.71 || txty 3.95 || twth 1.63 ||total 12.29 || size 512 || time: 11.18]
# [Epoch 2/3][Iter 210/517][lr 0.000244][Loss: cls 8.27 || txty 5.56 || twth 2.16 ||total 16.00 || size 512 || time: 11.17]
# [Epoch 2/3][Iter 220/517][lr 0.000258][Loss: cls 9.61 || txty 6.16 || twth 2.95 ||total 18.71 || size 512 || time: 11.20]
# [Epoch 2/3][Iter 230/517][lr 0.000272][Loss: cls 8.71 || txty 5.15 || twth 1.53 ||total 15.39 || size 512 || time: 11.14]
# [Epoch 2/3][Iter 240/517][lr 0.000287][Loss: cls 8.80 || txty 5.34 || twth 1.67 ||total 15.81 || size 512 || time: 11.21]
# [Epoch 2/3][Iter 250/517][lr 0.000303][Loss: cls 7.54 || txty 4.91 || twth 1.31 ||total 13.76 || size 512 || time: 11.17]
# [Epoch 2/3][Iter 260/517][lr 0.000319][Loss: cls 8.62 || txty 5.52 || twth 1.38 ||total 15.52 || size 512 || time: 11.19]
# [Epoch 2/3][Iter 270/517][lr 0.000336][Loss: cls 7.25 || txty 4.60 || twth 0.85 ||total 12.71 || size 512 || time: 11.16]
# [Epoch 2/3][Iter 280/517][lr 0.000353][Loss: cls 5.83 || txty 3.75 || twth 1.23 ||total 10.81 || size 512 || time: 11.17]
# [Epoch 2/3][Iter 290/517][lr 0.000371][Loss: cls 7.36 || txty 4.51 || twth 1.42 ||total 13.30 || size 512 || time: 11.14]
# [Epoch 2/3][Iter 300/517][lr 0.000390][Loss: cls 9.68 || txty 6.87 || twth 2.18 ||total 18.73 || size 512 || time: 11.11]
# [Epoch 2/3][Iter 310/517][lr 0.000409][Loss: cls 7.03 || txty 4.68 || twth 0.86 ||total 12.57 || size 512 || time: 11.16]
# [Epoch 2/3][Iter 320/517][lr 0.000429][Loss: cls 8.36 || txty 5.15 || twth 2.01 ||total 15.52 || size 512 || time: 11.18]
# [Epoch 2/3][Iter 330/517][lr 0.000450][Loss: cls 6.27 || txty 3.76 || twth 1.01 ||total 11.04 || size 512 || time: 11.16]
# [Epoch 2/3][Iter 340/517][lr 0.000472][Loss: cls 8.31 || txty 5.71 || twth 1.48 ||total 15.50 || size 512 || time: 11.16]
# [Epoch 2/3][Iter 350/517][lr 0.000494][Loss: cls 6.26 || txty 3.96 || twth 1.04 ||total 11.26 || size 512 || time: 11.16]
# [Epoch 2/3][Iter 360/517][lr 0.000518][Loss: cls 5.97 || txty 3.63 || twth 0.66 ||total 10.26 || size 512 || time: 11.19]
# [Epoch 2/3][Iter 370/517][lr 0.000542][Loss: cls 6.59 || txty 4.06 || twth 1.17 ||total 11.82 || size 512 || time: 11.17]
# [Epoch 2/3][Iter 380/517][lr 0.000566][Loss: cls 6.45 || txty 4.38 || twth 0.97 ||total 11.79 || size 512 || time: 11.19]
# [Epoch 2/3][Iter 390/517][lr 0.000592][Loss: cls 8.37 || txty 5.52 || twth 1.05 ||total 14.93 || size 512 || time: 11.09]
# [Epoch 2/3][Iter 400/517][lr 0.000619][Loss: cls 7.83 || txty 5.14 || twth 1.35 ||total 14.32 || size 512 || time: 11.15]
# [Epoch 2/3][Iter 410/517][lr 0.000646][Loss: cls 9.20 || txty 6.54 || twth 1.80 ||total 17.55 || size 512 || time: 11.21]
# [Epoch 2/3][Iter 420/517][lr 0.000674][Loss: cls 7.09 || txty 4.85 || twth 1.14 ||total 13.08 || size 512 || time: 11.14]
# [Epoch 2/3][Iter 430/517][lr 0.000704][Loss: cls 7.33 || txty 4.99 || twth 1.46 ||total 13.78 || size 512 || time: 11.13]
# [Epoch 2/3][Iter 440/517][lr 0.000734][Loss: cls 7.44 || txty 5.31 || twth 1.48 ||total 14.23 || size 512 || time: 11.21]
# [Epoch 2/3][Iter 450/517][lr 0.000765][Loss: cls 7.32 || txty 4.95 || twth 1.29 ||total 13.56 || size 512 || time: 11.17]
# [Epoch 2/3][Iter 460/517][lr 0.000797][Loss: cls 6.07 || txty 3.96 || twth 0.97 ||total 11.00 || size 512 || time: 11.17]
# [Epoch 2/3][Iter 470/517][lr 0.000830][Loss: cls 5.61 || txty 3.43 || twth 0.75 ||total 9.79 || size 512 || time: 11.14]
# [Epoch 2/3][Iter 480/517][lr 0.000864][Loss: cls 7.09 || txty 4.96 || twth 1.25 ||total 13.30 || size 512 || time: 11.13]
# [Epoch 2/3][Iter 490/517][lr 0.000900][Loss: cls 5.89 || txty 4.10 || twth 1.02 ||total 11.01 || size 512 || time: 11.17]
# [Epoch 2/3][Iter 500/517][lr 0.000936][Loss: cls 6.31 || txty 3.95 || twth 0.70 ||total 10.95 || size 512 || time: 11.16]
# [Epoch 2/3][Iter 510/517][lr 0.000973][Loss: cls 6.84 || txty 4.49 || twth 1.00 ||total 12.33 || size 512 || time: 11.17]
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# /content/utils/augmentations.py:242: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   mode = random.choice(self.sample_options)
# [Epoch 3/3][Iter 0/517][lr 0.001000][Loss: cls 8.36 || txty 6.05 || twth 1.65 ||total 16.06 || size 512 || time: 10.92]
# [Epoch 3/3][Iter 10/517][lr 0.001000][Loss: cls 7.71 || txty 5.42 || twth 1.22 ||total 14.35 || size 512 || time: 11.13]
# [Epoch 3/3][Iter 20/517][lr 0.001000][Loss: cls 8.36 || txty 6.06 || twth 1.36 ||total 15.78 || size 512 || time: 11.22]
# [Epoch 3/3][Iter 30/517][lr 0.001000][Loss: cls 6.87 || txty 4.75 || twth 0.79 ||total 12.40 || size 512 || time: 11.18]
# [Epoch 3/3][Iter 40/517][lr 0.001000][Loss: cls 7.56 || txty 5.94 || twth 1.26 ||total 14.76 || size 512 || time: 11.14]
# [Epoch 3/3][Iter 50/517][lr 0.001000][Loss: cls 9.28 || txty 6.59 || twth 1.43 ||total 17.30 || size 512 || time: 11.12]
# [Epoch 3/3][Iter 60/517][lr 0.001000][Loss: cls 6.01 || txty 4.04 || twth 0.62 ||total 10.67 || size 512 || time: 11.11]
# [Epoch 3/3][Iter 70/517][lr 0.001000][Loss: cls 5.69 || txty 4.22 || twth 0.77 ||total 10.68 || size 512 || time: 11.07]
# [Epoch 3/3][Iter 80/517][lr 0.001000][Loss: cls 5.82 || txty 3.85 || twth 0.78 ||total 10.45 || size 512 || time: 11.10]
# [Epoch 3/3][Iter 90/517][lr 0.001000][Loss: cls 5.54 || txty 3.75 || twth 0.79 ||total 10.08 || size 512 || time: 11.13]
# [Epoch 3/3][Iter 100/517][lr 0.001000][Loss: cls 6.71 || txty 4.52 || twth 1.14 ||total 12.37 || size 512 || time: 11.15]
# [Epoch 3/3][Iter 110/517][lr 0.001000][Loss: cls 6.29 || txty 3.97 || twth 0.51 ||total 10.77 || size 512 || time: 11.17]
# [Epoch 3/3][Iter 120/517][lr 0.001000][Loss: cls 7.02 || txty 4.90 || twth 1.11 ||total 13.03 || size 512 || time: 11.22]
# [Epoch 3/3][Iter 130/517][lr 0.001000][Loss: cls 7.50 || txty 5.20 || twth 1.23 ||total 13.93 || size 512 || time: 11.19]
# [Epoch 3/3][Iter 140/517][lr 0.001000][Loss: cls 7.69 || txty 5.08 || twth 0.81 ||total 13.58 || size 512 || time: 11.16]
# [Epoch 3/3][Iter 150/517][lr 0.001000][Loss: cls 8.07 || txty 6.07 || twth 1.01 ||total 15.15 || size 512 || time: 11.10]
# [Epoch 3/3][Iter 160/517][lr 0.001000][Loss: cls 7.64 || txty 5.44 || twth 1.20 ||total 14.28 || size 512 || time: 11.14]
# [Epoch 3/3][Iter 170/517][lr 0.001000][Loss: cls 7.68 || txty 6.33 || twth 1.93 ||total 15.94 || size 512 || time: 11.11]
# [Epoch 3/3][Iter 180/517][lr 0.001000][Loss: cls 6.58 || txty 5.32 || twth 0.73 ||total 12.63 || size 512 || time: 11.17]
# [Epoch 3/3][Iter 190/517][lr 0.001000][Loss: cls 7.11 || txty 5.39 || twth 0.92 ||total 13.42 || size 512 || time: 11.14]
# [Epoch 3/3][Iter 200/517][lr 0.001000][Loss: cls 4.89 || txty 3.09 || twth 0.48 ||total 8.47 || size 512 || time: 11.19]
# [Epoch 3/3][Iter 210/517][lr 0.001000][Loss: cls 5.38 || txty 3.77 || twth 0.43 ||total 9.58 || size 512 || time: 11.16]
# [Epoch 3/3][Iter 220/517][lr 0.001000][Loss: cls 5.54 || txty 4.41 || twth 0.69 ||total 10.64 || size 512 || time: 11.16]
# [Epoch 3/3][Iter 230/517][lr 0.001000][Loss: cls 6.00 || txty 5.03 || twth 0.92 ||total 11.94 || size 512 || time: 11.14]
# [Epoch 3/3][Iter 240/517][lr 0.001000][Loss: cls 6.18 || txty 4.92 || twth 0.77 ||total 11.87 || size 512 || time: 11.13]
# [Epoch 3/3][Iter 250/517][lr 0.001000][Loss: cls 7.01 || txty 5.50 || twth 0.88 ||total 13.39 || size 512 || time: 11.20]
# [Epoch 3/3][Iter 260/517][lr 0.001000][Loss: cls 8.85 || txty 6.47 || twth 2.36 ||total 17.68 || size 512 || time: 11.17]
# [Epoch 3/3][Iter 270/517][lr 0.001000][Loss: cls 5.04 || txty 4.08 || twth 0.36 ||total 9.48 || size 512 || time: 11.16]
# [Epoch 3/3][Iter 280/517][lr 0.001000][Loss: cls 6.15 || txty 4.65 || twth 0.67 ||total 11.47 || size 512 || time: 11.14]
# [Epoch 3/3][Iter 290/517][lr 0.001000][Loss: cls 7.24 || txty 5.16 || twth 0.84 ||total 13.24 || size 512 || time: 11.18]
# [Epoch 3/3][Iter 300/517][lr 0.001000][Loss: cls 6.59 || txty 5.25 || twth 0.74 ||total 12.57 || size 512 || time: 11.07]
# [Epoch 3/3][Iter 310/517][lr 0.001000][Loss: cls 6.82 || txty 5.10 || twth 1.08 ||total 13.00 || size 512 || time: 11.09]
# [Epoch 3/3][Iter 320/517][lr 0.001000][Loss: cls 4.90 || txty 3.62 || twth 0.52 ||total 9.04 || size 512 || time: 11.14]
# [Epoch 3/3][Iter 330/517][lr 0.001000][Loss: cls 5.22 || txty 3.68 || twth 0.87 ||total 9.77 || size 512 || time: 11.11]
# [Epoch 3/3][Iter 340/517][lr 0.001000][Loss: cls 6.25 || txty 4.95 || twth 1.09 ||total 12.29 || size 512 || time: 11.14]
# [Epoch 3/3][Iter 350/517][lr 0.001000][Loss: cls 4.65 || txty 3.70 || twth 0.46 ||total 8.81 || size 512 || time: 11.09]
# [Epoch 3/3][Iter 360/517][lr 0.001000][Loss: cls 5.82 || txty 4.95 || twth 0.81 ||total 11.59 || size 512 || time: 11.17]
# [Epoch 3/3][Iter 370/517][lr 0.001000][Loss: cls 5.93 || txty 4.26 || twth 0.61 ||total 10.80 || size 512 || time: 11.14]
# [Epoch 3/3][Iter 380/517][lr 0.001000][Loss: cls 5.47 || txty 4.04 || twth 0.45 ||total 9.96 || size 512 || time: 11.16]
# [Epoch 3/3][Iter 390/517][lr 0.001000][Loss: cls 5.28 || txty 3.81 || twth 1.22 ||total 10.31 || size 512 || time: 11.12]
# [Epoch 3/3][Iter 400/517][lr 0.001000][Loss: cls 5.47 || txty 3.85 || twth 0.46 ||total 9.78 || size 512 || time: 11.16]
# [Epoch 3/3][Iter 410/517][lr 0.001000][Loss: cls 8.44 || txty 5.97 || twth 1.62 ||total 16.03 || size 512 || time: 11.15]
# [Epoch 3/3][Iter 420/517][lr 0.001000][Loss: cls 5.88 || txty 4.49 || twth 0.67 ||total 11.04 || size 512 || time: 11.11]
# [Epoch 3/3][Iter 430/517][lr 0.001000][Loss: cls 7.64 || txty 6.03 || twth 0.99 ||total 14.65 || size 512 || time: 11.15]
# [Epoch 3/3][Iter 440/517][lr 0.001000][Loss: cls 5.87 || txty 4.70 || twth 1.11 ||total 11.69 || size 512 || time: 11.07]
# [Epoch 3/3][Iter 450/517][lr 0.001000][Loss: cls 4.75 || txty 3.18 || twth 0.44 ||total 8.37 || size 512 || time: 11.13]
# [Epoch 3/3][Iter 460/517][lr 0.001000][Loss: cls 6.61 || txty 5.71 || twth 0.97 ||total 13.28 || size 512 || time: 11.13]
# [Epoch 3/3][Iter 470/517][lr 0.001000][Loss: cls 7.01 || txty 5.35 || twth 0.67 ||total 13.03 || size 512 || time: 11.10]
# [Epoch 3/3][Iter 480/517][lr 0.001000][Loss: cls 5.41 || txty 4.32 || twth 0.53 ||total 10.26 || size 512 || time: 11.15]
# [Epoch 3/3][Iter 490/517][lr 0.001000][Loss: cls 6.34 || txty 5.09 || twth 0.67 ||total 12.10 || size 512 || time: 11.21]
# [Epoch 3/3][Iter 500/517][lr 0.001000][Loss: cls 6.96 || txty 5.52 || twth 1.04 ||total 13.52 || size 512 || time: 11.20]
# [Epoch 3/3][Iter 510/517][lr 0.001000][Loss: cls 6.10 || txty 4.54 || twth 0.69 ||total 11.33 || size 512 || time: 11.20]

# %%
# ! python test.py --cuda -d voc --trained_model
